# %% [markdown]
# ### Introducing Dataset

# %% [markdown]
# #### Problem Background
# CallIn PLC is a BPO solutions company based in Poland that handles incoming calls for various banks. They have dedicated teams for each of their clients. This case study is about the team that handles incoming calls for Royal Bank of Scotland (RBS) that is one of the banks that employs service solutions of CallIn PLC.
#
# RBS Team provides various services:
#
# ●	Information on transactions of checking and saving accounts of existing customers
#
# ●	Computer-generated voice information (through VRU = Voice Response Unit)
#
# ●	Information for prospective customers
#
# ●	Support for the customers of RBS’s website (internet customers)
#
# Dataset given along with the case study is for the month of February 1999 for one month’s call flow

# %% [markdown]
# #### Problem Introduction
# RBS, being large public sector bank, needs to get its accounts audited periodically for public reporting. During audit, in addition to conduct quarterly, half yearly and annual audits, the Board of Directors of the Bank randomly chose the accounts of a certain year to be audited for in-depth assessment of regularities in processes and accounts. This additional activity is done to ensure:
#
# ●	Any past irregularities by the then auditors
#
# ●	Any irregularity that was missed in earlier reporting
#
# ●	To account for any unknown/ unaccounted cash excess and/ or shortfall

# %% [markdown]
# #### Problem Statement
# RBS Board has hired services of Brent Associates to audit its accounts and the auditors have sought pay-out details to CallIn PLC. You are working with Brent Associates as data analyst and have been called in the team to render your services and investigate inconsistencies, if any. All information was tallied but the pay-outs given to CallIn PLC for the month of February 1999 were suspiciously incorrect and hence your major task is to audit this information and assess if payout has been accurately done and state exchequer has not been cheated upon.
#
# As per historical records, the RBS Team at CallIn PLC constituted of following team in February 1999:
#
# ●	8 agent positions
#
# ●	1 shift-supervisor position
#
# ●	5 agent positions for internet services (in an adjacent room)
#
# The team operated for:
#
# ●	During weekdays (Sunday to Thursday), the call centre is staffed from 7:00am to midnight.
#
# ●	During weekends (Friday-Saturday), it closes at 14:00 on Friday and reopens at around 20:00 on Saturday.
#
# ●	The automated service (VRU) operates 7 days a week, 24 hours a day.
#
# Below is the summary of compensation structure that was contracted between RBS and CallIn PLC in effect during the month of February 1999:
#
# ●	Fixed Charges: This is the fixed amount a minimum of which will be billed to RBS by CallIn PLC. This is non-negotiable and non-deductible even under the provisions of applied penalties (Refer later part of this section on clarification of penalties applicable on CallIn PLC).
#
# o	Operation sustenance fees: EUR 100,000/ month (The fixed fee is to be billed to RBS every month from the date of billing)
#
# o	Monthly third-party usage charges: This amount is charged in lieu of fixed third party vendors on boarded by CallIn PLC on behalf of RBS including but not limited to Cloud Telephone Services, Internet Connections, Network Maintenance and Server Maintenance Fees, Equipment AMC etc. This flat fee is EUR 20,000/ month
#
# ●	Variable Charges:
#
# o	VRU Call charges: These relate to the usage of VRU facility by RBS customers:
#
# ▪	Calls handled by VRU are not billed to RBS upto a duration of 120,000 seconds
#
# ▪	From 120,001st second onwards, VRU calls are charged at EUR 0.5/ second.
#
# o	Service Time Charges: This is the main avenue where CallIn PLC generates majority of revenue from the bank. This relates to calls that are transferred and handled by agents.
#
# ▪	Upto a total of 30,00,000 seconds, the RBS is billed at EUR 0.5/ second
#
# ▪	From 30,00,001st minute onwards, the bill is raised at EUR 1/ second.
#
# Apart from these charges, certain penalties are agreed and contracted which mandates CallIn PLC to be penalized in case of non-satisfactory servicing of agreement upto the standards of RBS bank:
#
# ●	Queuing of customers: RBS does not want its customers to wait in queue for unreasonably long periods. Hence:
#
# o	Queue time <= 1 minute per call is not penalized
#
# o	Queuing time > 1 and <= 3 minutes is penalized at EUR 0.5/ minute.
#
# o	Queuing time > 3 and <= 5 minutes is penalized at EUR 1/ minute.
#
# o	Any queuing time of > 5 minutes is penalized at EUR 2/ minute
#
# ●	Call Disconnection: Call disconnection penalty is levied over and above the queuing penalty
#
# o	Every customer that hangs up the call/ disconnects the call due to non-availability of agents is charged at EUR 10/ instance. These can be found by the calls where outcome is “AGENT” and server is “NO-SERVER”.
#
# o	If the outcome is “HANG” and server is “NO-SERVER”, the penalty is applied at EUR 5/ instance. These charges are over and above the queue time.

# %% [markdown]
# #### Description of Data:
#
# vru+line - Alpha numeric
# Each entering phone-call is first routed through a VRU: There are 6 VRUs labelled AA01 to AA06. Each VRU has several lines labelled 1-16. There are a total of 65 lines. Each call is assigned a VRU number and a line number.
#
# Call_id	- Numeric
# Each entering call is assigned a call id. Although they are different, the id’s are not necessarily consecutive due to being assigned to different VRUs.
#
# Customer_id - Numeric
# Upto 12 characters	This is the identification number of the caller, which identifies the customer uniquely; the ID is zero if the caller is not identified by the system (as is the case for prospective customers, for example).
#
# Priority - Numeric
# The priority is taken from an off-line file.
# There are two types of customers: (high-)priority and regular:
# ●	0 and 1 indicate unidentified customers or regular customers (to be elaborated on below)
# ●	2 indicates priority customers
# ●	Customers are served in the order of their "Time in Queue".
# ●	Priority customers are allocated at the outset of their call 1.5 minutes of waiting-time (in order to advance their position in the queue.) They are also exempt from paying a NIS 7 monthly fee, which regular customers must pay.
# ●	Customers have not been told about the existence of priorities.
# ●	Until August 1996, all the customers had the same priority - 0. Priorities 1 and 2 were introduced in August 1st, 1996. There still are 0 priority customers, but they are treated as Priority 1. (As we understand it, priority 0 corresponds to those customers that were assigned priority 0 before August 1st and whose priority has not been upgraded.)
# ●	Due to a system bug, customer I.D. was not recorded for those who did not wait in queue; hence, their priority is 0.
#
# Type - Text
# There are 6 different types of services:
# ●	PS - regular activity
# ●	PE - regular activity in English
# ●	IN - internet consulting
# ●	NE -stock exchange activity
# ●	NW - potential customer getting information
# ●	TT – customers who left a message asking the bank to return their call but, while the system returned their call, the calling-agent became busy hence the customers were put on hold in the queue.
#
# Date - Numeric
# Year-month-date (YYMMDD)
#
# vru_entry - Time
# Time that the phone-call enters the call-center. More specifically, each calling customer must first be identified, which is done by providing the VRU with the customer-id. Hence this is the time the call enters the VRU.
#
# vru_exit - Time
# Time of exit from the VRU: either to the queue, or directly to receive service, or to leave the system (abandonment).
#
# Q_start - Time
# Time of joining the queue (being put on “hold”). This entry is 00:00:00, for customers who have not reached the queue (abandoned from the VRU).
#
# Q_exit - Time
# Time (in seconds) of exiting the queue: either to receive service or due to abandonment.
#
# Outcome - Text
# There are 3 possible outcomes for each phone call:
# ●	AGENT – service
# ●	HANG - hung up
# ●	PHANTOM - a virtual call to be ignored (unclear to us – fortunately, there are only few of these.)
#
# Ser_start - Time
# Time of beginning of service by agent.
#
# Ser_exit - Time
# Time of end of service by agent.
#
# Server - String
# Name of the agent who served the call. This field is NO_SERVER, if no service was provided.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

import plotly.express as pe

# %% [markdown]
# ### Loading Dataset

# %%
df = pd.read_csv('february_data.csv')

# %%
print('Diplaying the first 5 rows of the data :-')
df.head(5)
# Out:
# Diplaying the first 5 rows of the data :-
#   vru+line  call_id  customer_id  priority type    date vru_entry  vru_exit  \
# 0   AA0101    34536          0.0         0   PS  990201  07:02:47  07:02:56
# 1   AA0101    34537          0.0         0   PS  990201  07:31:45  07:31:55
# 2   AA0101    34538          0.0         0   NW  990201  07:54:38  07:54:51
# 3   AA0101    34539   23317894.0         2   PS  990201  08:09:16  08:09:22
# 4   AA0101    34540   48178511.0         2   PS  990201  08:19:42  08:19:47
#
#     q_start    q_exit outcome ser_start  ser_exit     server
# 0  00:00:00  00:00:00   AGENT  07:02:55  07:05:41      DORIT
# 1  00:00:00  00:00:00   AGENT  07:31:54  07:31:59  NO_SERVER
# 2  00:00:00  00:00:00   AGENT  07:54:49  07:56:21       TOVA
# 3  08:09:22  08:09:27    HANG  00:00:00  00:00:00  NO_SERVER
# 4  08:19:47  08:20:21   AGENT  08:20:20  08:22:04     MICHAL

# %%
print('Diplaying the last 5 rows of the data :-')
df.tail(5)
# Out:
# Diplaying the last 5 rows of the data :-
#       vru+line  call_id  customer_id  priority type    date vru_entry  \
# 33339   AA0216     5607          0.0         0   IN  990226  14:14:43
# 33340   AA0216     5608          0.0         0   IN  990226  14:33:45
# 33341   AA0216     5609          0.0         0   IN  990228  11:29:39
# 33342   AA0216     5610          0.0         0   IN  990228  12:18:20
# 33343   AA0216     5611          0.0         0   IN  990228  16:01:22
#
#        vru_exit   q_start    q_exit outcome ser_start  ser_exit     server
# 33339  14:15:05  00:00:00  00:00:00    HANG  00:00:00  00:00:00  NO_SERVER
# 33340  14:33:50  00:00:00  00:00:00    HANG  00:00:00  00:00:00  NO_SERVER
# 33341  11:29:48  11:29:48  11:33:39    HANG  00:00:00  00:00:00  NO_SERVER
# 33342  12:18:30  12:18:30  12:18:49   AGENT  12:18:48  12:22:54       YITZ
# 33343  16:01:32  16:01:32  16:09:25    HANG  00:00:00  00:00:00  NO_SERVER

# %%
print('Displaying the basic informatiion of the data :-\n')
df.info()
# Out:
# Displaying the basic informatiion of the data :-
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33344 entries, 0 to 33343
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   vru+line     33344 non-null  object
#  1   call_id      33344 non-null  int64
#  2   customer_id  33344 non-null  float64
#  3   priority     33344 non-null  int64
#  4   type         33344 non-null  object
#  5   date         33344 non-null  int64
#  6   vru_entry    33344 non-null  object
#  7   vru_exit     33344 non-null  object
#  8   q_start      33344 non-null  object
#  9   q_exit       33344 non-null  object
#  10  outcome      33344 non-null  object
#  11  ser_start    33344 non-null  object
#  12  ser_exit     33344 non-null  object
#  13  server       33344 non-null  object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 3.6+ MB

# %%
print('Total no. of rows:',df.shape[0])
print('Total no. of columns:',df.shape[1])
# Out:
# Total no. of rows: 33344
# Total no. of columns: 14

# %%
df['vru'] = df['vru+line'].apply(lambda x : x[0:4])

# %%
df['date'].head(5)
# Out:
# 0    990201
# 1    990201
# 2    990201
# 3    990201
# 4    990201
# Name: date, dtype: int64

# %% [markdown]
# If we look at the **date** variable, the data format is not clear. Now we'll correct it giving a proper format using a dated_d function in the below cell.

# %%
def date_d(x):
    y = str(19*pow(10,len(str(x))) + x)
    return y[0:4] + '/'+y[4:6] + '/'+ y[-2:]
df['date'] = df['date'].apply(lambda x : date_d(int(x)))

# %%
df['date'].head(5)
# Out:
# 0    1999/02/01
# 1    1999/02/01
# 2    1999/02/01
# 3    1999/02/01
# 4    1999/02/01
# Name: date, dtype: object

# %%
df.dtypes
# Out:
# vru+line        object
# call_id          int64
# customer_id    float64
# priority         int64
# type            object
# date            object
# vru_entry       object
# vru_exit        object
# q_start         object
# q_exit          object
# outcome         object
# ser_start       object
# ser_exit        object
# server          object
# vru             object
# dtype: object

# %% [markdown]
# Here, the data types of **['vru_entry', 'vru_exit', 'date', 'q_start', 'q_exit', 'ser_start', 'ser_exit']** variables should be datetime. Now we'll change their data type

# %%
time_variable = ['vru_entry','vru_exit','date','q_start','q_exit','ser_start','ser_exit']
for i in time_variable:
    df[i] = pd.to_datetime(df[i])

# %%
df.dtypes
# Out:
# vru+line               object
# call_id                 int64
# customer_id           float64
# priority                int64
# type                   object
# date           datetime64[ns]
# vru_entry      datetime64[ns]
# vru_exit       datetime64[ns]
# q_start        datetime64[ns]
# q_exit         datetime64[ns]
# outcome                object
# ser_start      datetime64[ns]
# ser_exit       datetime64[ns]
# server                 object
# vru                    object
# dtype: object

# %%
df['vru_time'] = df['vru_exit']-df['vru_entry']
df['vru_time'] = df['vru_time'].apply(lambda x : x.seconds)

df['q_time'] = df['q_exit']-df['q_start']
df['q_time'] = df['q_time'].apply(lambda x : x.seconds)

df['ser_time'] = df['ser_exit']-df['ser_start']
df['ser_time'] = df['ser_time'].apply(lambda x : x.seconds)

# %%
df.head(5)
# Out:
#   vru+line  call_id  customer_id  priority type       date  \
# 0   AA0101    34536          0.0         0   PS 1999-02-01
# 1   AA0101    34537          0.0         0   PS 1999-02-01
# 2   AA0101    34538          0.0         0   NW 1999-02-01
# 3   AA0101    34539   23317894.0         2   PS 1999-02-01
# 4   AA0101    34540   48178511.0         2   PS 1999-02-01
#
#             vru_entry            vru_exit             q_start  \
# 0 2023-01-15 07:02:47 2023-01-15 07:02:56 2023-01-15 00:00:00
# 1 2023-01-15 07:31:45 2023-01-15 07:31:55 2023-01-15 00:00:00
# 2 2023-01-15 07:54:38 2023-01-15 07:54:51 2023-01-15 00:00:00
# 3 2023-01-15 08:09:16 2023-01-15 08:09:22 2023-01-15 08:09:22
# 4 2023-01-15 08:19:42 2023-01-15 08:19:47 2023-01-15 08:19:47
#
#                q_exit outcome           ser_start            ser_exit  \
# 0 2023-01-15 00:00:00   AGENT 2023-01-15 07:02:55 2023-01-15 07:05:41
# 1 2023-01-15 00:00:00   AGENT 2023-01-15 07:31:54 2023-01-15 07:31:59
# 2 2023-01-15 00:00:00   AGENT 2023-01-15 07:54:49 2023-01-15 07:56:21
# 3 2023-01-15 08:09:27    HANG 2023-01-15 00:00:00 2023-01-15 00:00:00
# 4 2023-01-15 08:20:21   AGENT 2023-01-15 08:20:20 2023-01-15 08:22:04
#
#       server   vru  vru_time  q_time  ser_time
# 0      DORIT  AA01         9       0       166
# 1  NO_SERVER  AA01        10       0         5
# 2       TOVA  AA01        13       0        92
# 3  NO_SERVER  AA01         6       5         0
# 4     MICHAL  AA01         5      34       104

# %%
col = ['vru_entry','vru_exit','q_start','q_exit','ser_start','ser_exit']
for i in col:
    df[i] = df[i].apply(lambda x : x.time())

# %%
df.head(5)
# Out:
#   vru+line  call_id  customer_id  priority type       date vru_entry  \
# 0   AA0101    34536          0.0         0   PS 1999-02-01  07:02:47
# 1   AA0101    34537          0.0         0   PS 1999-02-01  07:31:45
# 2   AA0101    34538          0.0         0   NW 1999-02-01  07:54:38
# 3   AA0101    34539   23317894.0         2   PS 1999-02-01  08:09:16
# 4   AA0101    34540   48178511.0         2   PS 1999-02-01  08:19:42
#
#    vru_exit   q_start    q_exit outcome ser_start  ser_exit     server   vru  \
# 0  07:02:56  00:00:00  00:00:00   AGENT  07:02:55  07:05:41      DORIT  AA01
# 1  07:31:55  00:00:00  00:00:00   AGENT  07:31:54  07:31:59  NO_SERVER  AA01
# 2  07:54:51  00:00:00  00:00:00   AGENT  07:54:49  07:56:21       TOVA  AA01
# 3  08:09:22  08:09:22  08:09:27    HANG  00:00:00  00:00:00  NO_SERVER  AA01
# 4  08:19:47  08:19:47  08:20:21   AGENT  08:20:20  08:22:04     MICHAL  AA01
#
#    vru_time  q_time  ser_time
# 0         9       0       166
# 1        10       0         5
# 2        13       0        92
# 3         6       5         0
# 4         5      34       104

# %%
df['Day_of_Week'] = df['date'].apply(lambda x : x.weekday())

# %%
df['Day_of_Week'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
def day_week(d):
    if d == 0:
        return 'Monday'
    elif d == 1:
        return 'Tuesday'
    elif d == 2:
        return 'Wednesday'
    elif d == 3:
        return 'Thusday'
    elif d == 4:
        return 'Friday'
    elif d == 5:
        return 'Saturday'
    else:
        return 'Sunday'

# %%
df['Day_of_Week'] = df['Day_of_Week'].apply(lambda x: day_week(x))
df['Day_of_Week'].head(5)
# Out:
# 0    Monday
# 1    Monday
# 2    Monday
# 3    Monday
# 4    Monday
# Name: Day_of_Week, dtype: object

# %%
df.head(5)
# Out:
#   vru+line  call_id  customer_id  priority type       date vru_entry  \
# 0   AA0101    34536          0.0         0   PS 1999-02-01  07:02:47
# 1   AA0101    34537          0.0         0   PS 1999-02-01  07:31:45
# 2   AA0101    34538          0.0         0   NW 1999-02-01  07:54:38
# 3   AA0101    34539   23317894.0         2   PS 1999-02-01  08:09:16
# 4   AA0101    34540   48178511.0         2   PS 1999-02-01  08:19:42
#
#    vru_exit   q_start    q_exit outcome ser_start  ser_exit     server   vru  \
# 0  07:02:56  00:00:00  00:00:00   AGENT  07:02:55  07:05:41      DORIT  AA01
# 1  07:31:55  00:00:00  00:00:00   AGENT  07:31:54  07:31:59  NO_SERVER  AA01
# 2  07:54:51  00:00:00  00:00:00   AGENT  07:54:49  07:56:21       TOVA  AA01
# 3  08:09:22  08:09:22  08:09:27    HANG  00:00:00  00:00:00  NO_SERVER  AA01
# 4  08:19:47  08:19:47  08:20:21   AGENT  08:20:20  08:22:04     MICHAL  AA01
#
#    vru_time  q_time  ser_time Day_of_Week
# 0         9       0       166      Monday
# 1        10       0         5      Monday
# 2        13       0        92      Monday
# 3         6       5         0      Monday
# 4         5      34       104      Monday

# %%
df.tail(5)
# Out:
#       vru+line  call_id  customer_id  priority type       date vru_entry  \
# 33339   AA0216     5607          0.0         0   IN 1999-02-26  14:14:43
# 33340   AA0216     5608          0.0         0   IN 1999-02-26  14:33:45
# 33341   AA0216     5609          0.0         0   IN 1999-02-28  11:29:39
# 33342   AA0216     5610          0.0         0   IN 1999-02-28  12:18:20
# 33343   AA0216     5611          0.0         0   IN 1999-02-28  16:01:22
#
#        vru_exit   q_start    q_exit outcome ser_start  ser_exit     server  \
# 33339  14:15:05  00:00:00  00:00:00    HANG  00:00:00  00:00:00  NO_SERVER
# 33340  14:33:50  00:00:00  00:00:00    HANG  00:00:00  00:00:00  NO_SERVER
# 33341  11:29:48  11:29:48  11:33:39    HANG  00:00:00  00:00:00  NO_SERVER
# 33342  12:18:30  12:18:30  12:18:49   AGENT  12:18:48  12:22:54       YITZ
# 33343  16:01:32  16:01:32  16:09:25    HANG  00:00:00  00:00:00  NO_SERVER
#
#         vru  vru_time  q_time  ser_time Day_of_Week
# 33339  AA02        22       0         0      Friday
# 33340  AA02         5       0         0      Friday
# 33341  AA02         9     231         0      Sunday
# 33342  AA02        10      19       246      Sunday
# 33343  AA02        10     473         0      Sunday

# %% [markdown]
# #### Detecting Null Values
# Checking whether the data has any null/np.nan values in it.

# %%
df.isnull().sum()
# Out:
# vru+line       0
# call_id        0
# customer_id    0
# priority       0
# type           0
# date           0
# vru_entry      0
# vru_exit       0
# q_start        0
# q_exit         0
# outcome        0
# ser_start      0
# ser_exit       0
# server         0
# vru            0
# vru_time       0
# q_time         0
# ser_time       0
# Day_of_Week    0
# dtype: int64

# %% [markdown]
# As can be seen, the null values is not present in the data.

# %% [markdown]
# #### Detecting Duplicate Values
# Now we'll check whether data has any duplicate values in it.

# %%
df.duplicated(keep = False).sum()
# Out:
# 0

# %% [markdown]
# Duplicate values are not present in the data.

# %% [markdown]
# #### Checking Unique values present in the each variables

# %%
df['vru+line'].unique()
# Out:
# array(['AA0101', 'AA0102', 'AA0103', 'AA0104', 'AA0105', 'AA0106',
#        'AA0107', 'AA0108', 'AA0109', 'AA0110', 'AA0111', 'AA0112',
#        'AA0113', 'AA0115', 'AA0116', 'AA0201', 'AA0202', 'AA0203',
#        'AA0204', 'AA0205', 'AA0206', 'AA0209', 'AA0210', 'AA0213',
#        'AA0214', 'AA0215', 'AA0216'], dtype=object)

# %% [markdown]
# In the vru+line variable, there are 27 distinct values present in it

# %%
df['priority'].unique()
# Out:
# array([0, 2, 1], dtype=int64)

# %% [markdown]
# In the priority variable, there are 3 distinct values present in it

# %%
df['type'].unique()
# Out:
# array(['PS', 'NW', 'NE', 'PE', 'TT', 'IN'], dtype=object)

# %% [markdown]
# In the type variable, there are 6 distinct values present in it

# %%
df['outcome'].unique()
# Out:
# array(['AGENT', 'HANG', 'PHANTOM'], dtype=object)

# %% [markdown]
# In the outcome variable, there are 3 distinct values present in it

# %%
df['server'].unique()
# Out:
# array(['DORIT', 'NO_SERVER', 'TOVA', 'MICHAL', 'KAZAV', 'YITZ', 'ZOHARI',
#        'YIFAT', 'GILI', 'DARMON', 'ANAT', 'AVNI', 'IDIT', 'BENSION',
#        'SHLOMO', 'AVIDAN', 'PINHAS', 'BASCH', 'SHARON', 'ELI', 'NAAMA',
#        'GELBER', 'MIKI', 'MORIAH', 'STEREN'], dtype=object)

# %% [markdown]
# In the server variable, there are 25 distinct values present in it

# %% [markdown]
# #### Descriptive Statistics

# %% [markdown]
# ##### 1. Data summary of  VRU_Time, Q_Time, Ser_Time

# %%
df[['vru_time','q_time','ser_time']].describe()
# Out:
#            vru_time        q_time      ser_time
# count  33344.000000  33344.000000  33344.000000
# mean      75.243132     41.791597    144.344320
# std     2363.196499     69.144811    207.906387
# min        0.000000      0.000000      0.000000
# 25%        6.000000      0.000000     15.000000
# 50%        9.000000      9.000000     80.000000
# 75%       11.000000     57.000000    180.000000
# max    86392.000000    908.000000   4264.000000

# %% [markdown]
# Out of above all three variables,
# 1. vru_time has the maximum seconds of call time i.e. 86392 seconds
# 2. ser_time has the maximum value of average call time i.e. 144 seconds
# 3. ser_time has the maximum call time i.e. 4812872.96 seconds

# %% [markdown]
# ##### 2. Grouping data based on VRU Unit i.e. AA01 & AA02

# %%
df.groupby(['vru'])[['vru_time','q_time','ser_time']].describe().transpose()
# Out:
# vru                     AA01          AA02
# vru_time count  16892.000000  16452.000000
#          mean      81.509827     68.808838
#          std     2484.366970   2232.008900
#          min        0.000000      0.000000
#          25%        6.000000      6.000000
#          50%        9.000000      9.000000
#          75%       11.000000     11.000000
#          max    86374.000000  86392.000000
# q_time   count  16892.000000  16452.000000
#          mean      40.689439     42.923231
#          std       68.280679     70.004982
#          min        0.000000      0.000000
#          25%        0.000000      0.000000
#          50%        8.000000     10.000000
#          75%       55.000000     58.000000
#          max      908.000000    749.000000
# ser_time count  16892.000000  16452.000000
#          mean     141.785697    146.971371
#          std      204.991279    210.831458
#          min        0.000000      0.000000
#          25%       14.000000     17.000000
#          50%       79.000000     82.000000
#          75%      178.000000    183.000000
#          max     4264.000000   3605.000000

# %% [markdown]
# Observations:
# 1. Between AA01 & AA02, AA01 has maximum no. of calls i.e. 16892.
# 2. Average voice response time of AA01 is more than that of AA02.
# 3. Queing time of AA02 is more than that of AA01.
# 4. AA01 has more total service time than AA02.

# %% [markdown]
# ##### 3. Grouping data based on Priority.

# %%
df.groupby(['priority'])[['vru_time','q_time','ser_time']].describe().transpose()
# Out:
# priority                   0             1             2
# vru_time count  19602.000000   4623.000000   9119.000000
#          mean      13.976992    248.252217    119.230179
#          std       32.822260   4572.166962   3130.177902
#          min        0.000000      0.000000      0.000000
#          25%        9.000000      5.000000      5.000000
#          50%       10.000000      6.000000      6.000000
#          75%       13.000000      6.000000      6.000000
#          max     1860.000000  86374.000000  86392.000000
# q_time   count  19602.000000   4623.000000   9119.000000
#          mean      23.872411     72.987021     64.495339
#          std       62.788107     73.727898     67.481657
#          min        0.000000      0.000000      0.000000
#          25%        0.000000     19.000000     18.000000
#          50%        0.000000     51.000000     43.000000
#          75%        4.000000    105.000000     86.000000
#          max      676.000000    730.000000    908.000000
# ser_time count  19602.000000   4623.000000   9119.000000
#          mean     128.337823    139.414233    181.250905
#          std      193.557305    203.675699    233.614016
#          min        0.000000      0.000000      0.000000
#          25%        7.000000      6.000000     46.000000
#          50%       69.000000     80.000000    108.000000
#          75%      159.000000    176.000000    227.000000
#          max     4264.000000   2982.000000   3736.000000

# %% [markdown]
# Observations:
# 1. No. of Low priority calls are more than that of High priority calls.
# 2. High Priority call has maximum length of call time in all the categories except service time

# %% [markdown]
# ##### 4. Grouping data based on Server.

# %%
df.groupby(['server'])[['vru_time','q_time','ser_time']].describe()
# Out:
#           vru_time                                                           \
#              count        mean          std  min  25%   50%    75%      max
# server
# ANAT        1219.0    9.267432     5.346823  0.0  6.0   9.0  12.00     63.0
# AVIDAN       881.0  106.442679  2908.790989  0.0  6.0   6.0  10.00  86346.0
# AVNI        1739.0    8.626222     4.420832  0.0  6.0   9.0  10.00     66.0
# BASCH       1169.0    8.884517     4.214437  0.0  6.0   9.0  10.00     31.0
# BENSION     1136.0   87.853873  2560.876747  0.0  6.0  12.0  16.00  86325.0
# DARMON       516.0  175.695736  3800.717263  0.0  5.0   6.0  10.25  86344.0
# DORIT       1050.0   90.293333  2665.313718  0.0  6.0   8.0  10.00  86374.0
# ELI          509.0    9.412574     3.648794  5.0  6.0  10.0  12.00     28.0
# GELBER       143.0  610.958042  7219.509116  2.0  5.5   6.0   9.00  86340.0
# GILI         614.0    7.910423     3.668586  0.0  6.0   6.0  10.00     32.0
# IDIT        1957.0   53.897803  1951.726988  0.0  6.0   9.0  12.00  86350.0
# KAZAV       1697.0  160.161461  3626.084724  0.0  5.0   6.0   9.00  86350.0
# MICHAL      1121.0  163.156111  3644.764483  4.0  6.0   9.0  11.00  86339.0
# MIKI        1293.0  142.635731  3394.668990  0.0  6.0   9.0  12.00  86358.0
# MORIAH      1226.0   78.991843  2465.294460  3.0  6.0   8.0  10.00  86329.0
# NAAMA        504.0  182.123016  3845.634020  0.0  6.0  11.0  14.00  86345.0
# NO_SERVER   6673.0   68.693541  2114.293286  0.0  6.0   9.0  10.00  86392.0
# PINHAS        40.0    5.850000     2.304399  1.0  5.0   6.0   6.00     11.0
# SHARON      1678.0    8.468415     3.932785  0.0  6.0   8.0  10.00     41.0
# SHLOMO       604.0  153.390728  3513.313843  0.0  7.0  10.0  13.00  86355.0
# STEREN      1049.0   90.256435  2665.383471  0.0  5.0   6.0  10.00  86335.0
# TOVA        1682.0    8.912604     3.839907  0.0  6.0   9.0  11.00     32.0
# YIFAT       1904.0   99.240021  2797.238267  0.0  6.0   9.0  10.00  86346.0
# YITZ        1794.0  104.815496  2881.938647  0.0  6.0   9.0  10.00  86348.0
# ZOHARI      1146.0    9.410995     4.754536  0.0  6.0  10.0  12.00     84.0
#
#            q_time             ...               ser_time              \
#             count       mean  ...    75%    max    count        mean
# server                        ...
# ANAT       1219.0  29.443806  ...  37.00  424.0   1219.0  150.776046
# AVIDAN      881.0  40.291714  ...  56.00  388.0    881.0  247.701476
# AVNI       1739.0  46.699827  ...  60.00  651.0   1739.0  256.491662
# BASCH      1169.0  40.190761  ...  50.00  584.0   1169.0  148.266039
# BENSION    1136.0  32.954225  ...  32.25  556.0   1136.0  139.924296
# DARMON      516.0  56.341085  ...  85.00  515.0    516.0  249.451550
# DORIT      1050.0  36.278095  ...  49.75  468.0   1050.0  198.186667
# ELI         509.0  37.988212  ...  46.00  749.0    509.0  393.249509
# GELBER      143.0  64.839161  ...  88.50  523.0    143.0  145.587413
# GILI        614.0  32.180782  ...  38.75  315.0    614.0  151.120521
# IDIT       1957.0  33.472151  ...  38.00  551.0   1957.0  122.551354
# KAZAV      1697.0  52.639364  ...  76.00  608.0   1697.0  191.403654
# MICHAL     1121.0  41.778769  ...  57.00  618.0   1121.0  146.816236
# MIKI       1293.0  43.739366  ...  59.00  455.0   1293.0  156.867749
# MORIAH     1226.0  44.434747  ...  65.00  453.0   1226.0  192.353181
# NAAMA       504.0  20.214286  ...  20.25  389.0    504.0  196.289683
# NO_SERVER  6673.0  42.903642  ...  59.00  908.0   6673.0    5.692043
# PINHAS       40.0  59.700000  ...  86.50  223.0     40.0  682.925000
# SHARON     1678.0  50.069130  ...  70.00  591.0   1678.0  129.902861
# SHLOMO      604.0  29.410596  ...  29.00  456.0    604.0  125.514901
# STEREN     1049.0  52.351764  ...  72.00  570.0   1049.0  194.625357
# TOVA       1682.0  38.035077  ...  54.00  438.0   1682.0  153.132580
# YIFAT      1904.0  51.015231  ...  70.00  676.0   1904.0  154.351891
# YITZ       1794.0  43.573579  ...  58.75  455.0   1794.0  173.824972
# ZOHARI     1146.0  29.145724  ...  29.00  477.0   1146.0  251.952880
#
#
#                   std   min     25%    50%     75%     max
# server
# ANAT       217.034987   0.0   41.00   93.0  180.00  3077.0
# AVIDAN     271.775815   1.0   80.00  151.0  304.00  2381.0
# AVNI       250.552814   0.0   95.00  176.0  328.00  2123.0
# BASCH      170.081035   0.0   51.00   87.0  176.00  1510.0
# BENSION    158.239242   0.0   47.75   92.0  170.25  1320.0
# DARMON     283.485497   0.0   80.75  153.0  304.00  2011.0
# DORIT      227.188069   0.0   64.25  121.5  248.00  2387.0
# ELI        424.199601   0.0  135.00  253.0  506.00  4264.0
# GELBER     178.061919   4.0   40.50   94.0  193.50  1333.0
# GILI       178.588233   1.0   52.25   96.0  177.50  2002.0
# IDIT       126.291767   0.0   48.00   84.0  155.00  1574.0
# KAZAV      205.829990   0.0   61.00  122.0  243.00  1802.0
# MICHAL     172.558313   0.0   39.00   88.0  188.00  1730.0
# MIKI       201.491272   0.0   31.00   86.0  201.00  1415.0
# MORIAH     241.801396   0.0   28.00  109.5  259.00  1759.0
# NAAMA      193.074094   0.0   71.00  131.0  243.25  1039.0
# NO_SERVER   48.202231   0.0    0.00    0.0    0.00  1401.0
# PINHAS     859.349109  11.0  189.25  368.5  756.50  3736.0
# SHARON     153.518863   0.0   47.00   84.0  152.00  2063.0
# SHLOMO     169.288301   0.0   44.75   78.0  134.25  1549.0
# STEREN     224.531003   0.0   66.00  129.0  242.00  2982.0
# TOVA       170.665673   0.0   58.00  105.0  191.00  2050.0
# YIFAT      186.215960   0.0   53.00   98.0  176.00  2005.0
# YITZ       193.906497   0.0   64.00  112.0  210.00  1908.0
# ZOHARI     267.641146   0.0   87.00  160.5  314.25  2576.0
#
# [25 rows x 24 columns]

# %% [markdown]
# Observations:
# 1. Out of all the servers, apart from NO_Server, IDIT has the most no. of calls.
# 2. PINHAS has the highest average service time.
# 3. PINHAS has the least number of calls assigned.

# %% [markdown]
# ##### 5. Grouping data based on Date & WeekDay.

# %%
df.groupby(['Day_of_Week'])[['vru_time','q_time','ser_time']].describe().T
# Out:
# Day_of_Week           Friday        Monday     Saturday        Sunday  \
# vru_time count   1950.000000   5777.000000   866.000000   6158.000000
#          mean      55.952821     69.651376    12.635104     94.732381
#          std     1954.970491   2271.207134    13.493681   2694.266855
#          min        0.000000      0.000000     0.000000      0.000000
#          25%        6.000000      6.000000     7.250000      6.000000
#          50%       10.000000      9.000000    10.000000      9.000000
#          75%       14.000000     10.000000    13.000000     12.000000
#          max    86340.000000  86355.000000   292.000000  86392.000000
# q_time   count   1950.000000   5777.000000   866.000000   6158.000000
#          mean      22.001538     39.606889    15.497691     33.402728
#          std       53.110817     65.191493    38.079420     64.837358
#          min        0.000000      0.000000     0.000000      0.000000
#          25%        0.000000      0.000000     0.000000      0.000000
#          50%        0.000000      8.000000     0.000000      0.000000
#          75%       20.000000     55.000000     7.000000     40.000000
#          max      730.000000    556.000000   399.000000    908.000000
# ser_time count   1950.000000   5777.000000   866.000000   6158.000000
#          mean     136.547179    151.267959   137.036952    137.764372
#          std      180.702317    207.579769   186.977711    210.217637
#          min        0.000000      0.000000     0.000000      0.000000
#          25%       18.250000     30.000000    10.250000     11.000000
#          50%       80.000000     88.000000    83.000000     73.000000
#          75%      175.000000    189.000000   179.000000    170.000000
#          max     1572.000000   3736.000000  2138.000000   4264.000000
#
# Day_of_Week          Thusday       Tuesday     Wednesday
# vru_time count   5839.000000   6398.000000   6356.000000
#          mean      83.338585     90.467334     53.130113
#          std     2525.658408   2642.469267   1875.456876
#          min        0.000000      0.000000      0.000000
#          25%        6.000000      6.000000      6.000000
#          50%        9.000000      8.000000      8.000000
#          75%       10.000000     10.000000     10.000000
#          max    86361.000000  86355.000000  86344.000000
# q_time   count   5839.000000   6398.000000   6356.000000
#          mean      49.463607     48.275242     47.984424
#          std       76.062811     71.509233     72.129427
#          min        0.000000      0.000000      0.000000
#          25%        0.000000      0.000000      0.000000
#          50%       15.000000     18.000000     15.000000
#          75%       69.000000     67.000000     68.000000
#          max      601.000000    749.000000    499.000000
# ser_time count   5839.000000   6398.000000   6356.000000
#          mean     152.898955    146.594092    137.690686
#          std      215.055389    208.482642    208.740713
#          min        0.000000      0.000000      0.000000
#          25%       24.000000     25.000000      3.000000
#          50%       85.000000     82.000000     73.000000
#          75%      194.000000    178.000000    172.000000
#          max     3605.000000   2734.000000   3077.000000

# %%
df.groupby(['date'])['vru_time'].describe()
# Out:
#              count        mean          std  min  25%   50%   75%      max
# date
# 1999-02-01  1567.0  229.561583  4357.655167  0.0  6.0   9.0  10.0  86355.0
# 1999-02-02  1846.0   55.471289  2009.545190  0.0  6.0   9.0  10.0  86348.0
# 1999-02-03  1949.0   62.875834  1955.844882  0.0  6.0   9.0  13.0  86339.0
# 1999-02-04  1371.0    9.757841     7.272767  0.0  6.0   9.0  12.0    202.0
# 1999-02-05   522.0  175.503831  3778.563905  0.0  6.0   9.0  12.0  86340.0
# 1999-02-06   210.0   12.157143     8.321821  0.0  7.0  10.0  13.0     60.0
# 1999-02-07  1542.0   66.100519  2198.635960  0.0  6.0   9.0  11.0  86343.0
# 1999-02-08  1190.0   10.422689    13.820500  0.0  6.0  10.0  13.0    447.0
# 1999-02-09  1436.0   70.452646  2278.414370  0.0  6.0   9.0  11.0  86345.0
# 1999-02-10  1697.0   61.241014  2095.984520  0.0  6.0   6.0  10.0  86344.0
# 1999-02-11  1745.0  256.553009  4616.233924  0.0  6.0   7.0  10.0  86361.0
# 1999-02-12   547.0   10.912249     8.784538  0.0  6.0   9.0  12.0     80.0
# 1999-02-13   246.0   12.471545    12.014158  0.0  6.0   9.0  13.0    120.0
# 1999-02-14  1588.0  119.380353  3063.456217  0.0  6.0  10.0  13.0  86374.0
# 1999-02-15  1510.0    9.813907    23.939961  0.0  6.0   9.0  10.0    860.0
# 1999-02-16  1726.0  109.615875  2938.492783  0.0  5.0   6.0  10.0  86355.0
# 1999-02-17  1473.0   66.845893  2249.183409  0.0  5.0   6.0   9.0  86329.0
# 1999-02-18  1387.0    8.876712     8.605173  0.0  6.0   9.0  10.0    273.0
# 1999-02-19   457.0   13.321663     7.694227  0.0  9.0  12.0  15.0     68.0
# 1999-02-20   214.0   11.686916     7.287530  0.0  8.0  10.0  13.0     57.0
# 1999-02-21  1667.0  166.913617  3661.091557  0.0  5.0   7.0  12.0  86392.0
# 1999-02-22  1510.0   10.219205    33.705862  0.0  5.0   6.0  10.0    989.0
# 1999-02-23  1390.0  133.843885  3271.604670  0.0  5.0   6.0  10.0  86350.0
# 1999-02-24  1237.0   10.315279    24.256768  0.0  6.0   8.0  11.0    631.0
# 1999-02-25  1336.0    9.909431    33.468729  0.0  5.0   6.0  10.0    915.0
# 1999-02-26   424.0   12.825472     9.984277  0.0  9.0  11.0  15.0    164.0
# 1999-02-27   196.0   14.387755    22.130213  0.0  9.0  11.0  14.0    292.0
# 1999-02-28  1361.0   10.002939    13.150542  0.0  6.0   9.0  12.0    339.0

# %% [markdown]
# Observations:
# 1. On **1999-02-03**, call centre has most no. of calls.

# %% [markdown]
# ##### 6. Grouping data based on Type.

# %% [markdown]
# **Type**:
#
# There are 6 different types of services:
#
# ● PS - regular activity
#
# ● PE - regular activity in English
#
# ● IN - internet consulting
#
# ● NE -stock exchange activity
#
# ● NW - potential customer getting information
#
# ● TT – customers who left a message asking the bank to return their call but, while the system returned their call, the calling-agent became busy hence the customers were put on hold in the queue.

# %%
df.groupby(['type'])[['vru_time','q_time','ser_time']].describe().transpose()
# Out:
# type                     IN           NE           NW           PE  \
# vru_time count   293.000000  2750.000000  7604.000000   149.000000
#          mean     12.037543     8.649455    12.042478     8.181208
#          std       7.203164    10.186227     7.702676    11.428422
#          min       1.000000     0.000000     0.000000     0.000000
#          25%       9.000000     6.000000     9.000000     4.000000
#          50%      10.000000     6.000000    10.000000     5.000000
#          75%      13.000000    10.000000    13.000000     9.000000
#          max      72.000000   275.000000   310.000000   130.000000
# q_time   count   293.000000  2750.000000  7604.000000   149.000000
#          mean     98.969283    52.929818    55.319963    48.275168
#          std     126.984072    79.513466    84.842208    75.818405
#          min       0.000000     0.000000     0.000000     0.000000
#          25%       0.000000     0.000000     0.000000     0.000000
#          50%      42.000000    19.000000    15.000000    18.000000
#          75%     164.000000    77.000000    77.000000    57.000000
#          max     618.000000   749.000000   676.000000   440.000000
# ser_time count   293.000000  2750.000000  7604.000000   149.000000
#          mean    178.870307   252.828364    70.656497   186.543624
#          std     312.042690   307.185883   128.478587   255.764711
#          min       0.000000     0.000000     0.000000     0.000000
#          25%       0.000000    60.500000     0.000000     3.000000
#          50%      71.000000   160.000000    32.000000    90.000000
#          75%     232.000000   326.750000    83.000000   247.000000
#          max    3077.000000  4264.000000  2005.000000  1415.000000
#
# type                      PS           TT
# vru_time count  21460.000000  1088.000000
#          mean     111.218173     1.895221
#          std     2945.136783     5.771967
#          min        0.000000     0.000000
#          25%        6.000000     0.000000
#          50%        6.000000     2.000000
#          75%       10.000000     2.000000
#          max    86392.000000    91.000000
# q_time   count  21460.000000  1088.000000
#          mean      35.701305    22.930147
#          std       59.008536    53.790872
#          min        0.000000     0.000000
#          25%        0.000000     0.000000
#          50%        7.000000     0.000000
#          75%       50.000000    17.000000
#          max      908.000000   468.000000
# ser_time count  21460.000000  1088.000000
#          mean     158.332992    94.151654
#          std      204.996970   180.050652
#          min        0.000000     0.000000
#          25%       40.000000     5.000000
#          50%       97.000000    18.000000
#          75%      197.250000   103.000000
#          max     3736.000000  1708.000000

# %% [markdown]
# Observations: Out of all the type of services, most no. of calls are for PS-regular activity while least no. of calls are for PE-regular activity in English.

# %% [markdown]
# ##### 7. Grouping data based on Outcome.

# %%
df.groupby(['outcome'])[['vru_time','q_time','ser_time']].describe().transpose()
# Out:
# outcome                AGENT          HANG       PHANTOM
# vru_time count  27162.000000   5904.000000    278.000000
#          mean      75.673367     47.262026    627.453237
#          std     2399.537637   1590.491390   7309.923364
#          min        0.000000      0.000000      0.000000
#          25%        6.000000      6.000000      5.000000
#          50%        9.000000      9.000000      6.000000
#          75%       11.000000     10.000000      6.750000
#          max    86374.000000  86392.000000  86361.000000
# q_time   count  27162.000000   5904.000000    278.000000
#          mean      40.774317     43.986280     94.575540
#          std       69.212377     66.909959     85.896796
#          min        0.000000      0.000000      3.000000
#          25%        0.000000      0.000000     29.000000
#          50%        6.000000     16.000000     68.000000
#          75%       54.000000     60.000000    136.250000
#          max      749.000000    908.000000    493.000000
# ser_time count  27162.000000   5904.000000    278.000000
#          mean     176.352993      1.158028     57.841727
#          std      217.138260     25.993912    143.390470
#          min        0.000000      0.000000      0.000000
#          25%       54.000000      0.000000      4.000000
#          50%      107.000000      0.000000      6.000000
#          75%      214.000000      0.000000     34.750000
#          max     4264.000000   1310.000000   1108.000000

# %% [markdown]
# Observations:
#     Most no. of the calls are transferred to the agent while least no. of calls are transferred to the phantom.

# %% [markdown]
# ### Univariate Analysis:

# %% [markdown]
# #### Continuous Variables
# Plotting Boxplot, Histogram and Distribution plot for the three continuous variables i.e. vru_time, q_time & ser_time.

# %%
figure, axis = plt.subplots(3,3,figsize = (20,20))

axis[0,0].hist(df['vru_time'],color="orange")
axis[0,0].set_title('Histogram of Voice Response Unit Time')
sns.boxplot(x=df['vru_time'], ax=axis[0,1],palette="Oranges")
axis[0,1].set_title('Boxplot of Voice Response Unit Time')
sns.distplot(df['vru_time'],ax = axis[0,2],color="orange", rug = True)
axis[0,2].set_title('Distribution Plot of Voice Response Unit Time')

axis[1,0].hist(df['q_time'],color="orange")
axis[1,0].set_title('Histogram of Queue Time')
sns.boxplot(x=df['q_time'], ax=axis[1,1],palette="Oranges")
axis[1,1].set_title('Boxplot of Queue Time')
sns.distplot(df['q_time'],ax = axis[1,2],color="orange",rug = True)
axis[1,2].set_title('Distribution Plot of Queue Time')

axis[2,0].hist(df['ser_time'],color="orange")
axis[2,0].set_title('Histogram of Service Time')
sns.boxplot(x=df['ser_time'], ax=axis[2,1],palette="Oranges")
axis[2,1].set_title('Boxplot of Service Time')
sns.distplot(df['ser_time'],ax = axis[2,2],color="orange", rug = True)
axis[2,2].set_title('Distribution Plot of Service Time')
# Out:
# Text(0.5, 1.0, 'Distribution Plot of Service Time')

# %% [markdown]
# **Observations**:
#
#     -- If we look at the distribution, we can say that, vru_time,q_time & ser_time has skewed distribution curve
#        towards the right side.
#
#     -- There are outliers present in all three variables.

# %% [markdown]
# ##### Categorical Variables

# %%
sns.countplot(x ='vru', data = df,color="darkorange")
plt.show()

# %% [markdown]
# **Observation**: Between AA01 & AA02, most no. of the calls attended by the AA01 unit.

# %%
plt.figure(figsize = (10,4))
sns.countplot(x = 'outcome', data = df,color="darkorange")
plt.show()

# %% [markdown]
# **Observation**: Most no. of the calls transferred to the AGENT while least no. to the PHANTOM.

# %%
sns.countplot(x ='priority', data = df, color = "darkorange")
plt.show()

# %% [markdown]
# **Observation**: Since here 1 is for low priority & 2 is for high priority, clearly stated that between these two, high priority calls are more.

# %%
plt.figure(figsize = (10,4))
sns.countplot(x ='Day_of_Week', data = df,color="darkorange")
plt.show()

# %% [markdown]
# **Observation**: Since during weekends (Friday-Saturday), it closes at 14:00 on Friday and reopens at around 20:00 on Saturday. Therefore, no. of calls are less on Friday & Saturday. Most of the numbers of calls are on Tuesday.

# %%
plt.figure(figsize = (20,8))
sns.countplot(x ='type', data = df,color="salmon", facecolor=(0, 0, 0, 0),linewidth=10,edgecolor=sns.color_palette('OrRd', 2))
plt.show()

# %% [markdown]
# **Observation**: Most no. of calls are come for PS type i.e. for regular activity, while least no. are for PE i.e. regular activity in English.

# %%
plt.figure(figsize = (20,8))
sns.countplot(x ='server', data = df,color="darkorange", alpha = 0.5)
plt.show()

# %% [markdown]
# **Observation**: Apart from NO_SERVER, most no. of calls transferred to IDIT

# %% [markdown]
# #### Bivariate Analysis

# %%
# preparing the variable for the diagram

# Type Variable 
# There are 6 different types of services: 
#     ● PS - regular activity 
#     ● PE - regular activity in English 
#     ● IN - internet consulting 
#     ● NE -stock exchange activity 
#     ● NW - potential customer getting information
#     ● TT – customers who left a message asking the bank to return their call but, 
#            while the system returned their call, the calling-agent became busy 
#            hence the customers were put on hold in the queue.


data = df
def calculate_percentage (priority_count, total_count,label):
    print ("Percentage of High Priority Calls for Type {} is {} %".format(label,round(((total_count * 100) / priority_count),2)))

type_ = ['PS', 'NW', 'NE', 'PE', 'TT', 'IN']
type_cat = []
type_priority = []
for var in type_:
    x = df['type'][data['type']==var].count()
    y = df['type'][(df['type']==var)&(df['priority']==2)].count()
    type_cat.append(x)
    type_priority.append(y)

_Server_Range = [x for x in range(1,len(type_)+1)]
plt.figure(figsize=(25,10))
plt.bar(type_ , type_cat,color='grey')
plt.bar(type_ , type_priority,color='pink', alpha = 0.7)
plt.title('Relation b/w Type & Priority calls', fontsize = 20)
plt.show()
print('Out of all the calls, percentage of High Priority calls for each call types of services:\n')
for i in range(len(type_cat)):
    calculate_percentage(type_cat[i],type_priority[i],type_[i])
# Out:
# Out of all the calls, percentage of High Priority calls for each call types of services:
#
# Percentage of High Priority Calls for Type PS is 33.95 %
# Percentage of High Priority Calls for Type NW is 0.41 %
# Percentage of High Priority Calls for Type NE is 50.44 %
# Percentage of High Priority Calls for Type PE is 34.9 %
# Percentage of High Priority Calls for Type TT is 33.36 %
# Percentage of High Priority Calls for Type IN is 0.0 %

# %%
type_ = ['PS', 'NW', 'NE', 'PE', 'TT', 'IN']
print('Out of total High Priority calls, the percentages of calls transferred to different service types are:\n')
for var in type_:
    x = round(100.00*df[df['priority'] == 2][df['type'] == var]['type'].count()/df[df['priority'] == 2].shape[0],2)
    print('{}% of total High Priority calls are came for {} service type.'.format(x,var))
# Out:
# Out of total High Priority calls, the percentages of calls transferred to different service types are:
#
# 79.9% of total High Priority calls are came for PS service type.
# 0.34% of total High Priority calls are came for NW service type.
# 15.21% of total High Priority calls are came for NE service type.
# 0.57% of total High Priority calls are came for PE service type.
# 3.98% of total High Priority calls are came for TT service type.
# 0.0% of total High Priority calls are came for IN service type.

# %% [markdown]
# **Observations**: Most no. of calls came for the PS type i.e. Regular Activity while the second most no. of calls came for NE i.e. Stock Exchange type. Also,IN type has least no. of calls.

# %%
# preparing the vairable for the diagram
server_ = ['DORIT', 'TOVA', 'MICHAL', 'KAZAV', 'YITZ', 'ZOHARI',
       'YIFAT', 'GILI', 'DARMON', 'ANAT', 'AVNI', 'IDIT', 'BENSION',
       'SHLOMO', 'AVIDAN', 'PINHAS', 'BASCH', 'SHARON', 'ELI', 'NAAMA',
       'GELBER', 'MIKI', 'MORIAH', 'STEREN']

data = df
def calculate_percentage (priority_count, total_count,label):
    print ("Percentage of High Priority Calls attended by {} is {} %".format(label,round(((total_count * 100) / priority_count),2)))

server_cat = []
server_priority = []
for var in server_:
    x = df['server'][data['server']==var].count()
    y = df['server'][(df['server']==var)&(df['priority']==2)].count()
    server_cat.append(x)
    server_priority.append(y)

_Server_Range = [x for x in range(1,len(server_)+1)]
plt.figure(figsize=(25,10))
plt.bar(server_ , server_cat,color='grey')
plt.bar(server_ , server_priority,color='yellow', alpha = 0.7)
plt.title('Relation b/w Server & Priority calls', fontsize = 20)
plt.show()
print('Between High and Low, the percentage of High Priority calls attended by different servers:\n')
for i in range(len(server_cat)):
    calculate_percentage(server_cat[i],server_priority[i],server_[i])
# Out:
# Between High and Low, the percentage of High Priority calls attended by different servers:
#
# Percentage of High Priority Calls attended by DORIT is 29.24 %
# Percentage of High Priority Calls attended by TOVA is 32.88 %
# Percentage of High Priority Calls attended by MICHAL is 27.03 %
# Percentage of High Priority Calls attended by KAZAV is 41.54 %
# Percentage of High Priority Calls attended by YITZ is 28.54 %
# Percentage of High Priority Calls attended by ZOHARI is 27.92 %
# Percentage of High Priority Calls attended by YIFAT is 31.51 %
# Percentage of High Priority Calls attended by GILI is 33.06 %
# Percentage of High Priority Calls attended by DARMON is 41.09 %
# Percentage of High Priority Calls attended by ANAT is 30.11 %
# Percentage of High Priority Calls attended by AVNI is 28.98 %
# Percentage of High Priority Calls attended by IDIT is 21.77 %
# Percentage of High Priority Calls attended by BENSION is 17.43 %
# Percentage of High Priority Calls attended by SHLOMO is 15.4 %
# Percentage of High Priority Calls attended by AVIDAN is 37.91 %
# Percentage of High Priority Calls attended by PINHAS is 50.0 %
# Percentage of High Priority Calls attended by BASCH is 26.26 %
# Percentage of High Priority Calls attended by SHARON is 33.55 %
# Percentage of High Priority Calls attended by ELI is 33.6 %
# Percentage of High Priority Calls attended by NAAMA is 22.82 %
# Percentage of High Priority Calls attended by GELBER is 39.86 %
# Percentage of High Priority Calls attended by MIKI is 27.38 %
# Percentage of High Priority Calls attended by MORIAH is 35.07 %
# Percentage of High Priority Calls attended by STEREN is 36.51 %

# %%
server_ = ['DORIT', 'TOVA', 'MICHAL', 'KAZAV', 'YITZ', 'ZOHARI',
       'YIFAT', 'GILI', 'DARMON', 'ANAT', 'AVNI', 'IDIT', 'BENSION',
       'SHLOMO', 'AVIDAN', 'PINHAS', 'BASCH', 'SHARON', 'ELI', 'NAAMA',
       'GELBER', 'MIKI', 'MORIAH', 'STEREN']
print('Out of total High Priority calls, the percentages of calls transferred to different servers are:\n')
for var in server_:
    x = round(100.00*df[df['priority'] == 2][df['server'] == var]['server'].count()/df[df['priority'] == 2].shape[0],2)
    print('{}% of total High Priority calls are transfered to {} server.'.format(x,var))
# Out:
# Out of total High Priority calls, the percentages of calls transferred to different servers are:
#
# 3.37% of total High Priority calls are transfered to DORIT server.
# 6.06% of total High Priority calls are transfered to TOVA server.
# 3.32% of total High Priority calls are transfered to MICHAL server.
# 7.73% of total High Priority calls are transfered to KAZAV server.
# 5.61% of total High Priority calls are transfered to YITZ server.
# 3.51% of total High Priority calls are transfered to ZOHARI server.
# 6.58% of total High Priority calls are transfered to YIFAT server.
# 2.23% of total High Priority calls are transfered to GILI server.
# 2.32% of total High Priority calls are transfered to DARMON server.
# 4.02% of total High Priority calls are transfered to ANAT server.
# 5.53% of total High Priority calls are transfered to AVNI server.
# 4.67% of total High Priority calls are transfered to IDIT server.
# 2.17% of total High Priority calls are transfered to BENSION server.
# 1.02% of total High Priority calls are transfered to SHLOMO server.
# 3.66% of total High Priority calls are transfered to AVIDAN server.
# 0.22% of total High Priority calls are transfered to PINHAS server.
# 3.37% of total High Priority calls are transfered to BASCH server.
# 6.17% of total High Priority calls are transfered to SHARON server.
# 1.88% of total High Priority calls are transfered to ELI server.
# 1.26% of total High Priority calls are transfered to NAAMA server.
# 0.63% of total High Priority calls are transfered to GELBER server.
# 3.88% of total High Priority calls are transfered to MIKI server.
# 4.72% of total High Priority calls are transfered to MORIAH server.
# 4.2% of total High Priority calls are transfered to STEREN server.

# %%
df['Day_of_Week'].unique()
# Out:
# array(['Monday', 'Tuesday', 'Wednesday', 'Thusday', 'Friday', 'Saturday',
#        'Sunday'], dtype=object)

# %%
# preparing the vairable for the diagram
weekday_ = ['Monday', 'Tuesday', 'Wednesday', 'Thusday', 'Friday', 'Saturday','Sunday']

data = df
def calculate_percentage (priority_count, total_count,label):
    print ("Percentage of High Priority Calls attended on {} is {} %".format(label,round(((total_count * 100) / priority_count),2)))

day_cat = []
day_priority = []
for var in weekday_:
    x = df['Day_of_Week'][data['Day_of_Week']==var].count()
    y = df['Day_of_Week'][(df['Day_of_Week']==var)&(df['priority']==2)].count()
    day_cat.append(x)
    day_priority.append(y)

_Day_Range = [x for x in range(1,len(weekday_)+1)]
plt.figure(figsize=(25,10))
plt.bar(weekday_ , day_cat,color='grey')
plt.bar(weekday_ , day_priority,color='yellow', alpha = 0.7)
plt.title('Relation b/w Day of Week & Priority calls', fontsize = 20)
plt.show()

for i in range(len(day_cat)):
    calculate_percentage(day_cat[i],day_priority[i],weekday_[i])
# Out:
# Percentage of High Priority Calls attended on Monday is 29.25 %
# Percentage of High Priority Calls attended on Tuesday is 30.2 %
# Percentage of High Priority Calls attended on Wednesday is 30.08 %
# Percentage of High Priority Calls attended on Thusday is 30.38 %
# Percentage of High Priority Calls attended on Friday is 14.46 %
# Percentage of High Priority Calls attended on Saturday is 13.97 %
# Percentage of High Priority Calls attended on Sunday is 22.86 %

# %%
plt.figure(figsize = (18,10))
sns.boxplot( x="ser_time", y='server', data=df)
plt.title('Boxplots of Service Time per Agent', fontsize = 15)
plt.show()

# %% [markdown]
# **Observations**: PINHAS has least no. of outliers. We can say that, time of calls has been consistent.

# %%
plt.figure(figsize = (12,6))
sns.boxplot( x="q_time", y='outcome', data=df)
plt.title('Boxplots of Queuing Time for Outcomes', fontsize = 15)
plt.show()

# %% [markdown]
# **Observations**: PHANTOM has the consistent queuing time length, having least presence of outliers.

# %%
plt.figure(figsize = (12,6))
sns.boxplot( x="ser_time", y='outcome', data=df)
plt.title('Boxplots of Servicing Time for Outcomes', fontsize = 15)
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.boxplot( x="vru_time", y='outcome', data=df)
plt.title('Boxplots of VRU Time for Outcomes', fontsize = 15)
plt.show()

# %% [markdown]
# #### Multivariate Analysis

# %%
df_corr = df.corr()
plt.figure(figsize = (10,6))
sns.heatmap(df_corr)
# Out:
# <AxesSubplot:>

# %%
df_corr['ser_time']
# Out:
# call_id        0.015215
# customer_id    0.011332
# priority       0.107428
# vru_time      -0.003033
# q_time         0.002259
# ser_time       1.000000
# Name: ser_time, dtype: float64

# %% [markdown]
# **Observations**: Only looking at the continuous variables, q_time is positvely co-related while vru_time is negatively co-related to the ser_time

# %%
sns.pairplot(df, hue = 'priority')

# %% [markdown]
# **Observations**: No patterns found

# %%
df.groupby('priority')[['q_time', 'vru_time', 'ser_time']].median().T.plot(kind='barh', figsize=(10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Contigency Table

# %%
pd.crosstab(df.server,df.priority, margins = True)
# Out:
# priority       0     1     2    All
# server
# ANAT         685   167   367   1219
# AVIDAN       424   123   334    881
# AVNI        1006   229   504   1739
# BASCH        715   147   307   1169
# BENSION      812   126   198   1136
# DARMON       211    93   212    516
# DORIT        578   165   307   1050
# ELI          307    31   171    509
# GELBER        60    26    57    143
# GILI         319    92   203    614
# IDIT        1313   218   426   1957
# KAZAV        754   238   705   1697
# MICHAL       676   142   303   1121
# MIKI         771   168   354   1293
# MORIAH       632   164   430   1226
# NAAMA        338    51   115    504
# NO_SERVER   4492  1099  1082   6673
# PINHAS        11     9    20     40
# SHARON       883   232   563   1678
# SHLOMO       455    56    93    604
# STEREN       467   199   383   1049
# TOVA         930   199   553   1682
# YIFAT       1014   290   600   1904
# YITZ        1032   250   512   1794
# ZOHARI       717   109   320   1146
# All        19602  4623  9119  33344

# %%
pd.crosstab(df.type,df.priority, margins = True)
# Out:
# priority      0     1     2    All
# type
# IN          293     0     0    293
# NE         1107   256  1387   2750
# NW         7539    34    31   7604
# PE           65    32    52    149
# PS        10259  3915  7286  21460
# TT          339   386   363   1088
# All       19602  4623  9119  33344

# %%
pd.crosstab(df.Day_of_Week,df.priority, margins = True)
# Out:
# priority         0     1     2    All
# Day_of_Week
# Friday        1471   197   282   1950
# Monday        3262   825  1690   5777
# Saturday       665    80   121    866
# Sunday        4048   702  1408   6158
# Thusday       3292   773  1774   5839
# Tuesday       3481   985  1932   6398
# Wednesday     3383  1061  1912   6356
# All          19602  4623  9119  33344

# %%
df.groupby('priority')[['q_time', 'vru_time', 'ser_time']].max()
# Out:
#           q_time  vru_time  ser_time
# priority
# 0            676      1860      4264
# 1            730     86374      2982
# 2            908     86392      3736

# %%
df.groupby('priority')[['q_time', 'vru_time', 'ser_time']].mean().T
# Out:
# priority           0           1           2
# q_time     23.872411   72.987021   64.495339
# vru_time   13.976992  248.252217  119.230179
# ser_time  128.337823  139.414233  181.250905

# %% [markdown]
# ### Audit Report:

# %% [markdown]
# ### **Fixed Charges**:
#
# This is the fixed amount a minimum of which will be billed to RBS by CallIn PLC. This is non-negotiable and non-deductible even under the provisions of applied penalties (Refer later part of this section on clarification of penalties applicable on CallIn PLC).
#
# 1. **Operation sustenance fees**: EUR 100,000/ month (The fixed fee is to be billed to RBS every month from the date of billing)
#
# 2. **Monthly third-party usage charges**: This amount is charged in lieu of fixed third party vendors on boarded by CallIn PLC on behalf of RBS including but not limited to Cloud Telephone Services, Internet Connections, Network Maintenance and Server Maintenance Fees, Equipment AMC etc. This flat fee is EUR 20,000/ month
#
#
# ### **Variable Charges**:
#
# 1. **VRU Call charges**: These relate to the usage of VRU facility by RBS customers:
#
# 2. Calls handled by VRU are not billed to RBS upto a duration of 120,000 seconds
#
# 3. From 120,001st second onwards, VRU calls are charged at EUR 0.5/ second.
#
# 4. **Service Time Charges**: This is the main avenue where CallIn PLC generates majority of revenue from the bank. This relates to calls that are transferred and handled by agents.
#
# 5. Upto a total of 30,00,000 seconds, the RBS is billed at EUR 0.5/ second
#
# 6. From 30,00,001st minute onwards, the bill is raised at EUR 1/ second.

# %%
#VRU Call Charges
total_vru_time = df['vru_time'].sum() # Total call time of voice response unit
chrg_vru_time = total_vru_time - 120000 # Deducting 120000 since charges will not be there for this time 
total_vru_chrg = chrg_vru_time*0.5 # Multiplying 0.5 EURO/sec charges to call time

print('Total VRU Time(seconds):',total_vru_time, 'sec')
print('Chargeble VRU Time(seconds):',chrg_vru_time, 'sec')
print('Total VRU Cal Charges @0.5 EUR/seconds:',total_vru_chrg,'EUR')
# Out:
# Total VRU Time(seconds): 2508907 sec
# Chargeble VRU Time(seconds): 2388907 sec
# Total VRU Cal Charges @0.5 EUR/seconds: 1194453.5 EUR

# %%
#Service Time Charges
total_ser_time = df['ser_time'].sum() # Total call time of service given to the customer
chrg_0 = 0.5*3000000 # Since upto 30 lacs seconds the charges are 0.5 EURO/sec 
chrg_1 = (total_ser_time - 3000000)*1 # From 30,00,001st minute onwards, the bill is raised at EUR 1/ second.
total_ser_chrg = chrg_0 + chrg_1 # Total service charge
print('Total Service Time(seconds):',total_ser_time,'sec')
print('Service Call Charges @0.5 EUR/seconds:',chrg_0,'EUR')
print('Service Call Charges @1 EUR/seconds:',chrg_1,'EUR')
print('Total Service Call Charges:',total_ser_chrg,'EUR')
# Out:
# Total Service Time(seconds): 4813017 sec
# Service Call Charges @0.5 EUR/seconds: 1500000.0 EUR
# Service Call Charges @1 EUR/seconds: 1813017 EUR
# Total Service Call Charges: 3313017.0 EUR

# %% [markdown]
# ### Penalties
#
# Apart from these charges, certain penalties are agreed and contracted which mandates CallIn PLC to be penalized in case of non-satisfactory servicing of agreement upto the standards of RBS bank:
#
# **Queuing of customers**: RBS does not want its customers to wait in queue for unreasonably long periods. Hence:
#
# 1. Queue time <= 1 minute per call is not penalized
#
# 2. Queuing time > 1 and <= 3 minutes is penalized at EUR 0.5/ minute.
#
# 3. Queuing time > 3 and <= 5 minutes is penalized at EUR 1/ minute.
#
# 4. Any queuing time of > 5 minutes is penalized at EUR 2/ minute
#
# 5. Call Disconnection: Call disconnection penalty is levied over and above the queuing penalty
#
# 6. Every customer that hangs up the call/ disconnects the call due to non-availability of agents is charged at EUR 10/ instance. These can be found by the calls where outcome is “AGENT” and server is “NO-SERVER”.
#
# 7. If the outcome is “HANG” and server is “NO-SERVER”, the penalty is applied at EUR 5/ instance. These charges are over and above the queue time.

# %%
# no. of instances of the calls where outcome is “AGENT” and server is “NO-SERVER”.
penalty_agent = (df[df['outcome']=='AGENT'][df['server']=='NO_SERVER'].shape[0])*10 
# no. of instances of the calls where outcome is “HANG” and server is “NO-SERVER”.
penalty_hang = (df[df['outcome']=='HANG'][df['server']=='NO_SERVER'].shape[0])*5

def queue_penalty(p):
    p_min = p/60
    val = int(p_min)
    if p_min <= 1:
        return 0
    elif p_min > 1 and p_min <= 3:
        return 0.5*val
    elif p_min > 3 and p_min <= 5:
        return 1*val
    elif p_min > 5:
        return 2*val
    
df['q_penalty'] = df['q_time'].apply(lambda x: queue_penalty(x))
print('Total penalties:', df['q_penalty'].sum() + penalty_agent + penalty_hang )
# Out:
# Total penalties: 47712.0

# %%
Fixed_Fee = 100000.00
TP_Usage = 20000.00
print('SCHEDULE OF PAYMENT TO CALLIN PLC')
print('PARTICULARS\t\t','AMOUNT(IN EURO)')
print('Fixed Fee:\t\t',Fixed_Fee)
print('TP Usage:\t\t',TP_Usage)
print('Total Fixed Billing:\t',Fixed_Fee+TP_Usage)
print('VRU Charge:\t\t',total_vru_chrg)
print('ST Charge:\t\t',total_ser_chrg)
print('Total Variable Billing:\t',total_vru_chrg+total_ser_chrg)
print('TOTAL BILLED AMOUNT:\t',total_vru_chrg+total_ser_chrg+Fixed_Fee+TP_Usage)
print('q_penalty:\t\t',df['q_penalty'].sum())
print('cd_penalty:\t\t',penalty_agent + penalty_hang)
print('Total Penalty:\t\t',df['q_penalty'].sum()+penalty_agent + penalty_hang)
print('TOTAL PAYABLE:\t\t',total_vru_chrg+total_ser_chrg+Fixed_Fee+TP_Usage-df['q_penalty'].sum()-penalty_agent-penalty_hang )
# Out:
# SCHEDULE OF PAYMENT TO CALLIN PLC
# PARTICULARS		 AMOUNT(IN EURO)
# Fixed Fee:		 100000.0
# TP Usage:		 20000.0
# Total Fixed Billing:	 120000.0
# VRU Charge:		 1194453.5
# ST Charge:		 3313017.0
# Total Variable Billing:	 4507470.5
# TOTAL BILLED AMOUNT:	 4627470.5
# q_penalty:		 13282.0
# cd_penalty:		 34430
# Total Penalty:		 47712.0
# TOTAL PAYABLE:		 4579758.5

# %% [markdown]
# **Observations**:
#
# 1. There are discrepancies in the VRU Charge, q_penalty from the given data.
#
# 2. The given calculation was incorrect according to the contract.
#
# 3. Correct Total Payable should be 4579758.5 EURO

# %% [markdown]
# # Questions:

# %% [markdown]
# #### Q1. In given document, CallIn PLC has claimed the employees were recruited in 2 shifts with each shift having total of 13 agents and 1 shift-supervisor. You see an inconsistency in these figures.
#
# Chose the correct option from below:
# 1. You don’t see any inconsistency and data is correct
# 2. Count of employees is 25
# 3. Count of employee is 23
# 4. Count of employees is 24
#
# **Answer**: Count of employees is 24

# %%
len(df[df['outcome'] == 'AGENT']['server'].unique())
# Out:
# 25

# %%
len(df[df['outcome'] == 'AGENT']['server'].unique())-1
# Out:
# 24

# %% [markdown]
# #### Q2. How many calls for internet consulting were hung up by customer despite the availability of a server:
# 1. 10
# 2. 94
# 3. 0
# 4. 17
#
# **Answer**: 0

# %%
df[(df['server'] != 'NO_SERVER')][(df['outcome'] == 'HANG')][df['type'] == 'IN'].shape[0]
# Out:
# 0

# %% [markdown]
# #### Q3. How many Phantom Calls were assigned to the agents?
# 1. 0
# 2. 11
# 3. 278
# 4. 94
#
# Hint: Server != No_Server AND outcome == Phantom
#
# **Answer**: 0

# %%
df[(df['server'] != 'NO_SERVER')][(df['outcome'] == 'PHANTOM')].shape[0]
# Out:
# 0

# %% [markdown]
# #### Q4. Which agent has the highest average service time?
# 1. Pinhas
# 2. Eli
# 3. Avidnan
# 4. Avni
#
# Hint: service_time average
#
# **Answer**: Pinhas

# %%
plt.figure(figsize = (16,4))
df.groupby(['server'])['ser_time'].mean().sort_values(ascending = False).plot(kind = 'bar', title = 'Average Service Time per Agent')
plt.show()

# %% [markdown]
# #### Q5. Which agent has the least number of calls assigned?
# 1. Idit
# 2. Tova
# 3. Gelber
# 4. Pinhas
#
# Hint: count of number of calls assigned to each agent
#
# **Answer**: Pinhas

# %%
plt.figure(figsize = (16,4))
df['server'].value_counts(ascending = True).plot(kind = 'bar', title = 'No. of Calls per Agent')
plt.show()

# %% [markdown]
# #### Q6. Which agent’s customers had to wait for the longest in order to speak to the agent?
# 1. Naama
# 2. Pinhas
# 3. Gelber
# 4. Darmon
#
# Hint: Find q_time for each server

# %%
df_1 = df.loc[df['server'] != 'NO_SERVER']
df_1.loc[df_1['q_time']==df_1['q_time'].max()][['server','q_time']]
# Out:
#       server  q_time
# 25506    ELI     749

# %%
df_1 = df.loc[df['outcome'] == 'AGENT']
df_1.groupby(['server'])['q_time'].max().sort_values(ascending = False)
# Out:
# server
# ELI          749
# YIFAT        676
# AVNI         651
# MICHAL       618
# KAZAV        608
# SHARON       591
# BASCH        584
# STEREN       570
# BENSION      556
# IDIT         551
# GELBER       523
# DARMON       515
# ZOHARI       477
# DORIT        468
# SHLOMO       456
# MIKI         455
# YITZ         455
# MORIAH       453
# TOVA         438
# ANAT         424
# NAAMA        389
# AVIDAN       388
# GILI         315
# PINHAS       223
# NO_SERVER    153
# Name: q_time, dtype: int64

# %%
df.loc[df['server'] != 'NO_SERVER'][['server','q_time']].sort_values(by = ['q_time'],ascending = False).head(1)
# Out:
#       server  q_time
# 25506    ELI     749

# %% [markdown]
# #### Q7. Based on description of data, queuing time of Phantom calls should be the highest. Is this assumption correct?
# 1. Yes
# 2. No
#
# Hint: Find q_time average for each outcome
#
# **Answer**: Yes

# %%
df.groupby(['outcome'])['q_time'].mean().plot(kind = 'bar', title = 'Average Queuing Time per Outcomes')
# Out:
# <AxesSubplot:title={'center':'Average Queuing Time per Outcomes'}, xlabel='outcome'>

# %% [markdown]
# #### Q8. Which of the following customers has made maximum number of calls (Chose customer ID)?
# 1. 101030
# 2. 58704610
# 3. 7191646
# 4. 57918849
#
# Hint: group by/ pivot
#
# **Answer**: 58704610

# %%
df['customer_id'].value_counts(ascending = False)
# Out:
# 0.0           19558
# 58704610.0      170
# 7191646.0       170
# 69687275.0      126
# 52867744.0      117
#               ...
# 59039180.0        1
# 38731493.0        1
# 38591798.0        1
# 17628579.0        1
# 10230043.0        1
# Name: customer_id, Length: 4081, dtype: int64

# %% [markdown]
# #### Q9. Calls from which of the following customers have been tagged as Phantom calls most number of times (Chose customer ID)?
# 1. 13408620
# 2. 24442634
# 3. 54613724
# 4. 25627027
#
# Hint: groupby customer id/ pivot
#
# **Answer**: 13408620

# %%
df[(df['customer_id']!=0.0)][df['outcome']=='PHANTOM']['customer_id'].value_counts(ascending = False).head(1)
# Out:
# 13408620.0    3
# Name: customer_id, dtype: int64

# %% [markdown]
# #### Q10. What percentage of high priority customer calls have been hung?
# 1. 9.97%
# 2. 19.88%
# 3. 20.79%
# 4. 11.02%
#
# Hint: count(priority == 2 AND outcome== Hang)
#
# **Answer**: 9.97%

# %%
print(round(100.0*df[df['priority']==2][df['outcome']=='HANG']['outcome'].count()/df[df['priority']==2]['outcome'].value_counts().sum(),2),'%')
# Out:
# 9.97 %

# %% [markdown]
# #### Q11. How many high priority customer calls have been tagged as Phantom?
# 1. 0.3%
# 2. 2.4%
# 3. 1.2%
# 4. 0.8%
#
# Hint: count(priority == 2 AND outcome== Phantom)
#
# **Answer**: 1.2%

# %%
print(round(100.0*df[(df['priority']==2)][df['outcome']=='PHANTOM'].shape[0]/df[(df['priority']==2)]['outcome'].count(),2),'%')
# Out:
# 1.2 %

# %% [markdown]
# #### Q12. Queuing time of high priority customers is shortest.
# 1. True
# 2. False
#
# Hint: Average of q_time by priority
#
# **Answer**: False

# %%
df.groupby(['priority'])['q_time'].mean().plot(kind = 'barh', title = 'Mean Queuing Time vs Priority')
# Out:
# <AxesSubplot:title={'center':'Mean Queuing Time vs Priority'}, ylabel='priority'>

# %% [markdown]
# #### Q13. High priority customers are focussed more by the agents with more time spent on servicing them.
# 1. True
# 2. False
#
# Hint: Average of ser_time by priority
#
# **Answer**: True

# %%
df.groupby(['priority'])['ser_time'].mean().plot(kind = 'barh', title = 'Mean Service Time vs Priority')
# Out:
# <AxesSubplot:title={'center':'Mean Service Time vs Priority'}, ylabel='priority'>

# %% [markdown]
# #### Q14. Average VRU time for high priority customers is the highest.
# 1. True
# 2. False
#
# Hint: Average of vru_time by priority
#
# **Answer**: False

# %%
df.groupby(['priority'])['vru_time'].mean().sort_values(ascending  = True).plot(kind = 'pie', title = 'Distribution of Average VRU Time taken for each type of Priority')
# Out:
# <AxesSubplot:title={'center':'Distribution of Average VRU Time taken for each type of Priority'}, ylabel='vru_time'>

# %% [markdown]
# #### Q15. Which of the following agents have received maximum number of high priority calls:
# 1. Kazav
# 2. Yifat
# 3. Sharon
# 4. Tova
#
# Hint: count of priority== 2 by agent (server)
#
# **Answer**: Kazav

# %%
df[df['priority']==2][df['server']!= 'NO_SERVER']['server'].value_counts(ascending = False).head(1)
# Out:
# KAZAV    705
# Name: server, dtype: int64

# %%
plt.figure(figsize = (10,6))
df[df['priority']==2][df['server']!= 'NO_SERVER']['server'].value_counts(ascending = False).plot(kind='bar', title='No. of High Priority Calls per Server')
# Out:
# <AxesSubplot:title={'center':'No. of High Priority Calls per Server'}>

# %% [markdown]
# #### Submission By:
#
# # Zashank Khare

# %% [markdown]
# ### Thanks & Happy Learning
